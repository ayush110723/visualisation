# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="darkgrid")

# %%
x=np.array([1,3,4,5,6,76,7,8,4,56,43,43,78,89,90])

# %%
y= np.sin(x)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
