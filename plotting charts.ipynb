# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs)
plt.show()

# %%
plt.plot(years, runs)
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Sachin Tendulkar's Yearly Runs")
plt.show()

# %%
import matplotlib.pyplot as plt

# Example years
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# Runs scored by each player
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

# Plotting
plt.plot(years, kohli, marker='o', label="Virat Kohli")
plt.plot(years, sehwag, marker='s', label="Virender Sehwag")

plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(years, kohli)
plt.plot(years, sehwag)
plt.legend(["Kohli", "Sehwag"])  # prone to mismatch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.plot(years, kohli)
#       2 plt.plot(years, sehwag)
#       3 plt.legend(["Kohli", "Sehwag"])  # prone to mismatch
#
# NameError: name 'kohli' is not defined

# %%
with plt.xkcd
# Out:
#   Cell In[10], line 1
#     with plt.xkcd
#                  ^
# SyntaxError: expected ':'
